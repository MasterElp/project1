# %%
import pandas as pd
import numpy as np
folder = 'd:/git/project1/generated'

# %%
btc_direct_table = pd.read_csv(f'{folder}/btc_daily_change_direct.csv')
btc_direct_table
# Out:
#       Unnamed: 0  direct   timestamp
# 0              0       0  1410912000
# 1              1       0  1410998400
# 2              2       0  1411084800
# 3              3       1  1411171200
# 4              4       0  1411257600
# ...          ...     ...         ...
# 2396        2396       1  1618012800
# 2397        2397       1  1618099200
# 2398        2398       0  1618185600
# 2399        2399       1  1618272000
# 2400        2400       0  1587168000
#
# [2401 rows x 3 columns]

# %%
date_time_title_short = pd.read_csv(f'{folder}/date_time_title_short.csv')

# %%
btc_timestamps = btc_direct_table['timestamp']
btc_direct =  btc_direct_table['direct']
news_timestamps_all = date_time_title_short['date']

# %%
def get_directs(news_timestamps):
    directs = []
    for news_timestamp in news_timestamps:
        #print(ts_news)
        finded = False
        for i in range(btc_direct.shape[0]):
            if news_timestamp == btc_timestamps[i]:
                directs.append(btc_direct[i])
                finded = True
                break;
        if (not finded):
            print('not finded')
            directs.append(0)    
    return directs

# %%
def get_union_table(num):
    table = pd.read_csv(f'{folder}/classification_{num*1000}_{(num+1)*1000-1}.csv')
    table['timestamp'] = np.array(news_timestamps_all[num*1000:(num+1)*1000-1])
    table['direct'] = get_directs(table['timestamp'])
    return table

# %%
# %%time
res_table = pd.DataFrame(None)
res_table = res_table.append(get_union_table(1), sort=False, ignore_index=True)
res_table
# Out:
# not finded
# Wall time: 13.4 s
#      Unnamed: 0         0         1         2         3         4         5  \
# 0             0 -0.713249 -0.283814 -0.101295 -0.341170  0.043982 -0.172246
# 1             1 -0.981232 -0.517633 -0.104585 -0.159411 -0.599754 -0.057241
# 2             2 -0.329825  0.177008 -0.057989 -0.156781  0.034756 -0.011628
# 3             3 -0.453778 -0.393633 -0.436847 -0.426423 -0.093593  0.010150
# 4             4 -0.068871 -0.076212  0.040244 -0.119434 -0.266157 -0.452937
# ..          ...       ...       ...       ...       ...       ...       ...
# 994         994 -0.520707 -0.487373  0.144352  0.063050  0.106835 -0.189484
# 995         995 -0.012538 -0.452542  0.167107  0.047215 -0.331293 -0.220291
# 996         996 -0.362439 -0.355747  0.476702 -0.260408 -0.943103 -0.023870
# 997         997  0.169624 -0.067058 -0.158985 -0.295147 -0.060189 -0.441862
# 998         998 -0.394736  0.032571  0.153030  0.184908 -0.277255 -0.673968
#
#             6         7         8  ...       760       761       762  \
# 0    0.447011 -0.036035 -0.380066  ...  0.893797 -0.459837  0.279001
# 1    0.754283  0.532321 -0.257174  ...  0.950622  0.094646  0.082928
# 2    0.179180  0.360941 -0.212696  ...  0.073430 -0.044928  0.235481
# 3    1.026766  0.791641 -0.333138  ...  0.365006 -0.304121 -0.081564
# 4   -0.201964  0.118581  0.164386  ... -0.124684 -0.240935  0.123414
# ..        ...       ...       ...  ...       ...       ...       ...
# 994  0.081531  0.314267 -0.153992  ... -0.334263 -0.240833  0.092752
# 995  0.866564  0.184508 -0.031477  ...  0.309732 -0.363114  0.069599
# 996  0.514249  0.663708 -0.509982  ...  0.591386  0.024250  0.524859
# 997  0.217594  0.927954 -0.810537  ...  0.308782 -0.077360 -0.095935
# 998  0.538810  1.053351 -0.053055  ... -0.102281 -0.257655  0.243929
#
#           763       764       765       766       767   timestamp  direct
# 0   -0.341229 -0.166162 -0.454428  0.631444 -0.013104  1558310400       0
# 1    0.021525 -0.425796 -0.336343  0.577183  0.245995  1568419200       1
# 2   -0.092122  0.007695 -0.165196  0.413334  0.548612  1601510400       0
# 3   -0.097217  0.046622 -0.985997 -0.691530 -0.080297  1604448000       1
# 4    0.058175 -0.393713 -0.218862  0.468281  0.426958  1563840000       0
# ..        ...       ...       ...       ...       ...         ...     ...
# 994 -0.130132 -0.270268 -0.030455  0.034798  0.224623  1596758400       0
# 995 -0.153434 -0.094220 -0.283501  0.416555  0.148161  1550793600       1
# 996  0.207623 -0.409921 -0.378747  0.055286  0.367741  1584576000       1
# 997 -0.633258 -0.025333 -0.267030 -0.184257  0.096888  1585699200       1
# 998  0.061871 -0.294445 -0.335691  0.656285  0.343614  1596412800       1
#
# [999 rows x 771 columns]

# %%
start = 394
for j in range(60):
    res_table = pd.DataFrame(None)
    for i in range(10):
        num = i+j*10+start
        print(num)
        res_table = res_table.append(get_union_table(num), sort=False, ignore_index=True)
    res_table.to_csv(f'{folder}\set_{num}.csv')
# Out:
# 204
# not finded
# not finded
# not finded
# not finded
# 205
# not finded
# not finded
# not finded
# not finded
# not finded
# 206
# not finded
# not finded
# not finded
# 207
# not finded
# not finded
# 208
# not finded
# 209
# not finded
# 210
# not finded
# not finded
# 211
# not finded
# not finded
# 212
# 213
# not finded
# not finded
# not finded
# not finded
# 214
# not finded
# not finded
# 215
# not finded
# 216
# 217
# 218
# not finded
# not finded
# not finded
# 219
# not finded
# not finded
# 220
# not finded
# not finded
# not finded
# 221
# not finded
# 222
# not finded
# 223
# 224
# not finded
# 225
# not finded
# not finded
# 226
# not finded
# 227
# not finded
# not finded
# 228
# not finded
# not finded
# 229
# not finded
# 230
# not finded
# not finded
# not finded
# 231
# not finded
# not finded
# not finded
# 232
# 233
# not finded
# not finded
# 234
# not finded
# 235
# not finded
# 236
# not finded
# 237
# not finded
# not finded
# 238
# not finded
# not finded
# 239
# not finded
# not finded
# 240
# not finded
# not finded
# 241
# 242
# not finded
# not finded
# not finded
# not finded
# 243
# not finded
# not finded
# not finded
# not finded
# 244
# not finded
# not finded
# 245
# not finded
# not finded
# 246
# not finded
# not finded
# not finded
# not finded
# 247
# not finded
# not finded
# 248
# not finded
# 249
# 250
# not finded
# not finded
# 251
# 252
# 253
# not finded
# not finded
# not finded
# 254
# not finded
# not finded
# 255
# not finded
# 256
# not finded
# 257
# not finded
# 258
# not finded
# 259
# not finded
# 260
# not finded
# 261
# not finded
# 262
# not finded
# not finded
# not finded
# 263
# not finded
# 264
# not finded
# not finded
# not finded
# 265
# not finded
# not finded
# not finded
# not finded
# 266
# 267
# not finded
# not finded
# not finded
# 268
# not finded
# 269
# not finded
# not finded
# not finded
# 270
# not finded
# not finded
# 271
# not finded
# not finded
# not finded
# 272
# not finded
# not finded
# not finded
# 273
# not finded
# 274
# 275
# 276
# not finded
# not finded
# not finded
# not finded
# 277
# not finded
# not finded
# 278
# 279
# not finded
# not finded
# not finded
# 280
# not finded
# not finded
# not finded
# 281
# 282
# not finded
# not finded
# 283
# not finded
# 284
# 285
# not finded
# not finded
# not finded
# 286
# not finded
# not finded
# not finded
# 287
# not finded
# 288
# 289
# not finded
# 290
# not finded
# not finded
# not finded
# 291
# not finded
# not finded
# 292
# 293
# not finded
# not finded
# 294
# not finded
# not finded
# 295
# 296
# not finded
# 297
# not finded
# not finded
# 298
# not finded
# 299
# not finded
# not finded
# not finded
# not finded
# not finded
# not finded
# not finded
# 300
# not finded
# not finded
# not finded
# 301
# 302
# not finded
# 303
# not finded
# 304
# 305
# 306
# not finded
# 307
# not finded
# not finded
# not finded
# 308
# not finded
# not finded
# not finded
# not finded
# not finded
# 309
# not finded
# not finded
# not finded
# not finded
# not finded
# not finded
# 310
# not finded
# not finded
# 311
# not finded
# 312
# not finded
# not finded
# not finded
# not finded
# 313
# not finded
# not finded
# not finded
# 314
# not finded
# not finded
# 315
# not finded
# not finded
# not finded
# 316
# not finded
# not finded
# not finded
# 317
# not finded
# not finded
# not finded
# 318
# not finded
# 319
# 320
# not finded
# not finded
# 321
# not finded
# not finded
# not finded
# 322
# not finded
# 323
# not finded
# 324
# not finded
# not finded
# not finded
# 325
# not finded
# not finded
# 326
# not finded
# 327
# not finded
# not finded
# 328
# not finded
# 329
# 330
# not finded
# not finded
# not finded
# not finded
# 331
# not finded
# not finded
# 332
# not finded
# not finded
# not finded
# 333
# not finded
# not finded
# not finded
# 334
# not finded
# not finded
# 335
# not finded
# not finded
# 336
# not finded
# not finded
# 337
# not finded
# not finded
# not finded
# 338
# 339
# not finded
# not finded
# not finded
# 340
# 341
# not finded
# not finded
# 342
# not finded
# 343
# not finded
# not finded
# 344
# not finded
# not finded
# 345
# not finded
# 346
# not finded
# not finded
# not finded
# 347
# not finded
# 348
# not finded
# 349
# not finded
# not finded
# 350
# not finded
# 351
# not finded
# not finded
# 352
# 353
# not finded
# not finded
# not finded
# 354
# 355
# not finded
# 356
# not finded
# not finded
# not finded
# not finded
# 357
# not finded
# not finded
# 358
# 359
# not finded
# 360
# not finded
# not finded
# 361
# not finded
# not finded
# not finded
# 362
# not finded
# not finded
# not finded
# 363
# not finded
# not finded
# not finded
# not finded
# not finded
# not finded
# 364
# not finded
# not finded
# 365
# not finded
# not finded
# not finded
# 366
# 367
# not finded
# not finded
# 368
# not finded
# not finded
# 369
# not finded
# not finded
# not finded
# not finded
# 370
# not finded
# 371
# not finded
# 372
# 373
# not finded
# not finded
# 374
# not finded
# not finded
# not finded
# 375
# not finded
# 376
# not finded
# not finded
# 377
# not finded
# not finded
# not finded
# not finded
# not finded
# not finded
# not finded
# 378
# not finded
# not finded
# 379
# not finded
# not finded
# not finded
# not finded
# 380
# not finded
# not finded
# not finded
# not finded
# not finded
# 381
# not finded
# not finded
# not finded
# not finded
# 382
# not finded
# not finded
# 383
# not finded
# 384
# 385
# not finded
# 386
# not finded
# not finded
# 387
# not finded
# not finded
# 388
# not finded
# not finded
# not finded
# not finded
# not finded
# 389
# not finded
# 390
# 391
# not finded
# 392
# not finded
# not finded
# 393
# not finded
# 394
# not finded
# not finded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6fd257c4f121> in <module>
#       5         num = i+j*10+start
#       6         print(num)
# ----> 7         res_table = res_table.append(get_table(num), sort=False, ignore_index=True)
#       8     res_table.to_csv(f'{folder}\set_{num}.csv')
#
# <ipython-input-5-a475a5205865> in get_table(num)
#       8         for i in range(btc_direct.shape[0]):
#       9             #print(btc_direct.loc[i,:])
# ---> 10             if ts_news == btc_direct.loc[i,:].timestamp:
#      11                 directs.append(btc_direct.loc[i,:].direct)
#      12                 finded = True
#
# D:\git\project1\ml\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# D:\git\project1\ml\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# D:\git\project1\ml\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     805                 # We don't need to check for tuples here because those are
#     806                 #  caught by the _is_nested_tuple_indexer check above.
# --> 807                 section = self._getitem_axis(key, axis=i)
#     808
#     809                 # We should never have a scalar section here, because
#
# D:\git\project1\ml\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# D:\git\project1\ml\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# D:\git\project1\ml\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3775         # this could be a view
#    3776         # but only in a single-dtyped view sliceable case
# -> 3777         result._set_is_copy(self, copy=not result._is_view)
#    3778         return result
#    3779
#
# D:\git\project1\ml\lib\site-packages\pandas\core\generic.py in _is_view(self)
#    4008     def _is_view(self) -> bool_t:
#    4009         """Return boolean indicating if self is view of another array """
# -> 4010         return self._mgr.is_view
#    4011
#    4012     @final
#
# D:\git\project1\ml\lib\site-packages\pandas\core\internals\managers.py in is_view(self)
#     705         """ return a boolean if we are a single block and are a view """
#     706         if len(self.blocks) == 1:
# --> 707             return self.blocks[0].is_view
#     708
#     709         # It is technically possible to figure out which blocks are views
#
# D:\git\project1\ml\lib\site-packages\pandas\core\internals\blocks.py in is_view(self)
#     209         values = self.values
#     210         values = cast(np.ndarray, values)
# --> 211         return values.base is not None
#     212
#     213     @property
#
# KeyboardInterrupt:

# %%
btc_direct_table.loc[btc_direct_table.timestamp == 1550793600, :]
# Out:
#       Unnamed: 0  direct   timestamp
# 1619        1619       1  1550793600

# %%
data = pd.read_csv(f'{folder}/set_133.csv')

# %%
for i in range(14, 40):
    print (i)
    data_add = pd.read_csv(f'{folder}/set_{i}3.csv')
    data = data.append(data_add, sort=False, ignore_index=True)

# %%
data.to_csv(f'{folder}/set_393.csv')
