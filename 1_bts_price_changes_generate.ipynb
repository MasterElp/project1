# %%
import pandas as pd
import numpy as np
folder = 'd:\git\project1'

# %%
btc_usd_df = pd.read_csv(f'{folder}/BTC-USD.csv', delimiter=',')
btc_usd_df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2396  2021-04-09  58326.562500  58937.046875  57807.863281  58245.003906
# 2397  2021-04-10  58253.777344  61276.664063  58038.707031  59793.234375
# 2398  2021-04-11  59846.230469  60790.554688  59289.796875  60204.964844
# 2399  2021-04-12  60175.945313  61253.035156  59589.875000  59893.453125
# 2400  2021-04-13  60292.875000  63152.812500  59892.859375  62944.847656
#
#          Adj Close        Volume
# 0       457.334015  2.105680e+07
# ...

# %%
def get_change(df, period):
    change = []
    #print(df.shape[0])
    for i in range(df.shape[0]):
        if (i >= period):
            change.append(df.Open[i] - df.Open[i-period])
        else:
            change.append(0)
    return change

# %%
period = 2
btc_usd_df[f'change_{period}_day'] = get_change(btc_usd_df, period)
btc_usd_df
# Out:
# 2401
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2396  2021-04-09  58326.562500  58937.046875  57807.863281  58245.003906
# 2397  2021-04-10  58253.777344  61276.664063  58038.707031  59793.234375
# 2398  2021-04-11  59846.230469  60790.554688  59289.796875  60204.964844
# 2399  2021-04-12  60175.945313  61253.035156  59589.875000  59893.453125
# 2400  2021-04-13  60292.875000  63152.812500  59892.859375  62944.847656
#
#          Adj Close        Volume  change_2_day
# ...

# %%
import time, datetime
def get_timestamp(date):
    return int(time.mktime(datetime.datetime.strptime(date, "%Y-%m-%d").timetuple()))

btc_usd_df['timestamp'] = btc_usd_df['Date'].apply(get_timestamp)
btc_usd_df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2396  2021-04-09  58326.562500  58937.046875  57807.863281  58245.003906
# 2397  2021-04-10  58253.777344  61276.664063  58038.707031  59793.234375
# 2398  2021-04-11  59846.230469  60790.554688  59289.796875  60204.964844
# 2399  2021-04-12  60175.945313  61253.035156  59589.875000  59893.453125
# 2400  2021-04-13  60292.875000  63152.812500  59892.859375  62944.847656
#
#          Adj Close        Volume  change_2_day   timestamp
# ...

# %%
nan_rows = btc_usd_df[btc_usd_df['Open'].isnull()]
nan_rows
# Out:
#             Date  Open  High  Low  Close  Adj Close  Volume  change_2_day  \
# 2039  2020-04-17   NaN   NaN  NaN    NaN        NaN     NaN           NaN
# 2214  2020-10-09   NaN   NaN  NaN    NaN        NaN     NaN           NaN
# 2217  2020-10-12   NaN   NaN  NaN    NaN        NaN     NaN           NaN
# 2218  2020-10-13   NaN   NaN  NaN    NaN        NaN     NaN           NaN
#
#        timestamp
# 2039  1587074400
# 2214  1602194400
# 2217  1602453600
# 2218  1602540000

# %%
btc_usd_df = btc_usd_df.dropna()
btc_usd_df.corr()['change_2_day'].sort_values()
# Out:
# timestamp       0.094397
# Volume          0.141577
# High            0.200584
# Open            0.201546
# Close           0.201844
# Adj Close       0.201844
# Low             0.204419
# change_2_day    1.000000
# Name: change_2_day, dtype: float64

# %%
df.to_csv(f'{folder}/generated/bts_price_changes.csv')
